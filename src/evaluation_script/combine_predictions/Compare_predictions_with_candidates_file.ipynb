# %%
import pandas as pd

# %%
dfPerfect = pd.read_csv("candidates_V2.csv")

# %%
dfPerfect
# Out:
#                                                 seriesuid      coordX  \
# 0       1.3.6.1.4.1.14519.5.2.1.6279.6001.100225287222...   68.420000
# 1       1.3.6.1.4.1.14519.5.2.1.6279.6001.100225287222...  -95.209361
# 2       1.3.6.1.4.1.14519.5.2.1.6279.6001.100225287222...  -24.766755
# 3       1.3.6.1.4.1.14519.5.2.1.6279.6001.100225287222...  -63.080000
# 4       1.3.6.1.4.1.14519.5.2.1.6279.6001.100225287222...   52.946688
# 5       1.3.6.1.4.1.14519.5.2.1.6279.6001.100225287222...   54.657731
# 6       1.3.6.1.4.1.14519.5.2.1.6279.6001.100225287222...  134.730000
# 7       1.3.6.1.4.1.14519.5.2.1.6279.6001.100225287222...   84.804055
# 8       1.3.6.1.4.1.14519.5.2.1.6279.6001.100225287222...  -76.470000
# 9       1.3.6.1.4.1.14519.5.2.1.6279.6001.100225287222...  -38.560000
# 10      1.3.6.1.4.1.14519.5.2.1.6279.6001.100225287222...   90.102285
# 11      1.3.6.1.4.1.14519.5.2.1.6279.6001.100225287222...  -20.101006
# ...

# %%
dfALL = pd.read_csv("predictions_ALL.csv")

# %%
dfALL.shape
# Out:
# (754962, 5)

# %%
dfPerfect.shape
# Out:
# (754975, 5)

# %%
s = dfALL["seriesuid"].values[4500]  #4500 #10

# %%
dfPerfect[(dfPerfect["seriesuid"]==s) & (dfPerfect["class"]==1)]
# Out:
#                                                seriesuid      coordX  \
# 56764  1.3.6.1.4.1.14519.5.2.1.6279.6001.124154461048...  146.239444
#
#            coordY      coordZ  class
# 56764 -161.190112 -310.777295      1

# %%
b = dfALL[(dfALL["seriesuid"]==s) & (dfALL["probability"]>0.9)].copy()
b["coordX"]-=64
b["coordY"]-=64
b["coordZ"]-=64
b
# Out:
#                                               seriesuid      coordX  \
# 4895  1.3.6.1.4.1.14519.5.2.1.6279.6001.124154461048...  146.239444
#
#           coordY      coordZ  probability
# 4895 -161.190112 -310.777295     0.990747
